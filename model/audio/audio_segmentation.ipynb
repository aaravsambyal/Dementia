# %% [markdown]
# #### Standard imports with Pydub
#
# Pydub is a library for performing segmentation and other tasks on audio files

# %%
import os

import pandas as pd
import numpy as np

from pydub import AudioSegment

# %% [markdown]
# #### Storing paths

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access the environment variables
train_ad = os.environ.get("TRAIN_AD")
train_cn = os.environ.get("TRAIN_CN")
segmentation_ad = os.environ.get("SEGMENTATION_AD")
segmentation_cn = os.environ.get("SEGMENTATION_CN")
final_segmented_train_ad = os.environ.get("FINAL_SEGMENTED_TRAIN_AD")
final_segmented_train_cn = os.environ.get("FINAL_SEGMENTED_TRAIN_CN")
test = os.environ.get("TEST_AUDIO")
segmentation_test = os.environ.get("SEGMENTATION_TEST")
final_segmented_test = os.environ.get("FINAL_SEGMENTED_TEST")

# %% [markdown]
# #### Segmenting training audios

# %% [markdown]
# Defining function for reading the segmentation csv file for the corresponding audio file

# %%
def load_segmentation_data(segmentation_file):

    return pd.read_csv(segmentation_file)

# %% [markdown]
# Defining function for extracting only the patient speech segment

# %%
def extract_patient_speech(audio_file, segmentation_data, output_path):
    # Load the audio file
    audio = AudioSegment.from_file(audio_file)

    # Initialize an empty segment to store the patient's speech
    final_audio_segment = AudioSegment.silent()

    # Store pointers to INV parts of the audio
    prev_end = 0

    # Iterate through each segment in the segmentation data
    for _, segment in segmentation_data.iterrows():
        start_time = int(segment['begin'])
        end_time = int(segment['end'])
        speaker = segment['speaker']

        if speaker == 'INV':
            if start_time == prev_end:
                # If continous INV segments, append to the previous INV segment
                prev_end = end_time

            else:
                # Ignoring the INV segment and appending audio till the start of this segment
                final_audio_segment += audio[prev_end:start_time]
                prev_end = end_time   


    # Append the audio after the last INV segment or if segmentation only had PAR segments
    final_audio_segment += audio[prev_end:]

    # Save the final audio segment to a new file
    output_file = os.path.join(output_path, os.path.basename(audio_file))
    final_audio_segment.export(output_file, format="wav")

    return output_file

# %%
output_directory = final_segmented_train_ad

for audio_file in os.listdir(train_ad):
    audio_file_path = train_ad + audio_file
    segmentation_path = segmentation_ad + audio_file[:-4] + ".csv"

    segmentation_data = load_segmentation_data(segmentation_path)
    output_file_path = extract_patient_speech(audio_file_path, segmentation_data, output_directory)
    print(f"Final segmented audio file saved at: {output_file_path}")
# Out:
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso024.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso025.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso027.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso028.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso031.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso032.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso033.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso035.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso036.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso039.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso043.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso045.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso046.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso047.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso049.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso053.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso054.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso055.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso056.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso059.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso060.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso063.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso068.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso070.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso071.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso072.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso074.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso075.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso077.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso078.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso089.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso090.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso092.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso093.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso098.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso106.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso109.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso110.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso112.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso116.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso122.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso123.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso125.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso126.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso128.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso130.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso134.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso138.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso141.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso142.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso144.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso187.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso188.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso189.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso190.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso192.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso197.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso198.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso200.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso202.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso205.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso206.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso209.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso211.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso212.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso215.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso216.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso218.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso220.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso222.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso223.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso224.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso228.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso229.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso232.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso233.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso234.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso236.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso237.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso244.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso245.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso246.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso247.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso248.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso249.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso250.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/ad/adrso253.wav

# %%
output_directory = final_segmented_train_cn

for audio_file in os.listdir(train_cn):
    audio_file_path = train_cn + audio_file
    segmentation_path = segmentation_cn + audio_file[:-4] + ".csv"

    segmentation_data = load_segmentation_data(segmentation_path)
    output_file_path = extract_patient_speech(audio_file_path, segmentation_data, output_directory)
    print(f"Final segmented audio file saved at: {output_file_path}")
# Out:
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso002.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso003.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso005.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso007.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso008.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso010.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso012.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso014.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso015.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso016.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso017.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso018.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso019.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso021.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso022.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso023.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso148.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso151.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso152.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso153.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso154.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso156.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso157.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso158.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso159.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso160.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso161.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso162.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso164.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso165.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso167.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso168.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso169.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso170.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso172.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso173.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso177.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso178.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso180.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso182.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso183.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso186.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso257.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso259.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso260.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso261.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso262.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso263.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso264.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso265.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso266.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso267.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso268.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso270.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso273.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso274.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso276.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso277.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso278.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso280.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso281.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso283.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso285.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso286.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso289.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso291.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso292.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso296.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso298.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso299.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso300.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso302.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso307.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso308.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso309.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso310.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso312.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso315.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-train/train/final_segmented_audio/cn/adrso316.wav

# %%
output_directory = final_segmented_test

for audio_file in os.listdir(test):
    audio_file_path = test + audio_file
    segmentation_path = segmentation_test + audio_file[:-4] + ".csv"

    segmentation_data = load_segmentation_data(segmentation_path)
    output_file_path = extract_patient_speech(audio_file_path, segmentation_data, output_directory)
    print(f"Final segmented audio file saved at: {output_file_path}")
# Out:
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt1.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt10.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt11.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt12.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt13.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt14.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt15.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt16.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt17.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt18.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt19.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt2.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt20.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt21.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt22.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt23.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt24.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt25.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt26.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt27.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt28.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt29.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt3.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt30.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt31.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt32.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt33.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt34.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt35.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt36.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt37.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt38.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt39.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt4.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt40.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt41.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt42.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt43.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt44.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt45.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt46.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt47.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt48.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt49.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt5.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt50.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt51.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt52.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt53.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt54.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt55.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt56.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt57.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt58.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt59.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt6.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt60.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt61.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt62.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt63.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt64.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt65.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt66.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt67.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt68.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt69.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt7.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt70.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt71.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt8.wav
# Final segmented audio file saved at: Data/ADReSSo21-diagnosis-test/test-dist/final_segmented_audio/adrsdt9.wav
